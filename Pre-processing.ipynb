# %%
import pandas as pd

# %%
d = pd.read_csv("Tables/Postdoc_data_2016.csv")
list(d.columns.values)
# Out:
# ['Institution',
#  'Title',
#  'Annual Salary',
#  'FTE',
#  'APPT FTR BASIS',
#  'APPT FRACTION',
#  'AMOUNT OF SALARY PAID FROM GENERAL FUND',
#  '%',
#  'FTE.1',
#  'Time',
#  'PAY_FRCTN',
#  'Last Name',
#  'First Names',
#  'Department',
#  'FT/PT',
#  'Contract Length',
#  'Degree',
#  'Highest Education Level',
#  'Type',
#  'Effective Date',
#  'Hire Date']

# %% [markdown]
# ## 1. Ethnea

# %%
#Create the two new columns (sex and ethnicity) and fill them with True/False depending on the presence of last/first name
d["Ethnea"] = d["Last Name"].notnull()
d["Genni"] = d["First Names"].notnull()

# %%
from urllib.request import urlopen
import ast

# %%
#Set up querry
for i in range(len(d)):
    url = "http://abel.lis.illinois.edu/cgi-bin/ethnea/search.py?Fname=FIRSTNAME&Lname=LASTNAME&format=json"
    if d["Genni"][i] == True or d["Ethnea"][i] == True:
        if d["Genni"][i] == True:
            fname = d["First Names"][i]
            if (' ' in fname) == True:
                fname = fname.split()
                fname = "%20".join(fname)
        else:
            fname = ""
        if d["Ethnea"][i] == True:
            lname = d["Last Name"][i]
            if (' ' in lname) == True:
                lname = lname.split()
                lname = "%20".join(lname)
        else:
            lname = ""
        url = url.replace('FIRSTNAME',fname).replace('LASTNAME',lname)
#Perform querry
        data = ast.literal_eval(urlopen(url).read().rstrip().decode('UTF-8'))
        d.loc[i, "Ethnea"] = data['Ethnea']
        d.loc[i, "Genni"] = data['Genni']

# %%
 d.to_csv("Tables/Gendered.csv")

# %%
d = pd.read_csv("Tables/Gendered.csv")

# %% [markdown]
# ## 2. Salary annualization

# %%
import math

# %%
d["AdjSalary"] = 1
for i in range(len(d)):
    d.loc[i,"AdjSalary"] = d["Annual Salary"][i].replace('$',"").replace(',',"").replace('*',"")
    frq = 1
    if math.isnan(d["%"][i]) == False:
        frq = float(d["%"][i])
    if math.isnan(d["FTE"][i]) == False:
        frq = float(d["FTE"][i])
    if math.isnan(d["FTE.1"][i]) == False:
        frq = float(d["FTE.1"][i])
    if math.isnan(d["Time"][i]) == False:
        frq = float(d["Time"][i])
    if math.isnan(d["PAY_FRCTN"][i]) == False:
        frq = float(d["PAY_FRCTN"][i])
    if frq > 1:
        d.loc[i,"AdjSalary"] = float(d.loc[i,"AdjSalary"]) / (frq/100)
    if frq <= 1:
        d.loc[i,"AdjSalary"] = float(d.loc[i,"AdjSalary"]) / frq

# %% [markdown]
# ## 3. Total number of postdocs

# %%
d["PostdocNum"] = 0.1
univ = list(set(d["Institution"]))
for i in range(len(univ)):
    num = sum([1 for j in list(d["Institution"]) if j==univ[i]])
    ind = d.loc[d["Institution"] == univ[i]].index
    d.loc[ind, "PostdocNum"] = num

# %% [markdown]
# ## 4. Postdoc titles

# %%
#Turn 91 different titles into a handfull of defining words
words = {'Fellow':["fellow"],
        'Associate': ["asso", "aso"],
        'Researcher' : ["res","not_resident"],
         'Scholar' : ["scholar"],
         'Intern' : ["intern"],
         'Trainee' : ["trainee"],
         'Teaching' : ["teach"],
         'Senior' : ["senior", "sr"],
         'Assistant' : ["asst"],
         'Clinical' : ["clinical"], 
        'Assistant' : ["asst", "assistant"],
        'Faculty' : ["fac"]}

for word in words.keys():
    d[word] = 0

# %%
import re

# %%
for i in range(len(d)):
    target = d.loc[i,"Title"].lower()
    for word in words.keys():
        search_result = 0
        if len(words[word]) == 1:
            search_result = len(re.findall(words[word][0], target))
        if len(words[word]) > 1:
            if "not_" in words[word][1]:
                word1 = re.sub("not_","",words[word][1])
                search_result = len(re.findall(words[word][0], target)) - len(re.findall(word1, target))
            else:
                search_result = len(re.findall(words[word][0], target)) + len(re.findall(words[word][1], target))
        if search_result>0:
            d.loc[i, word] = 1

# %% [markdown]
# ## 5. NIH grants

# %%
univ_info = pd.read_csv("Univ_info.csv")

# %%
d["NIH_grants"] = ""
d["NIH_order"] = 0
for i in range(len(d)):
    for j in range(len(univ_info)):
        if univ_info.loc[j, "University_FoiA"].strip() == d.loc[i, "Institution"].strip():
            d.loc[i, "NIH_grants"] = univ_info.loc[j, "2017_NIH"]
            d.loc[i, "NIH_order"] = univ_info.loc[j,"NIH_top"]

# %%
#Final mega-table
list(d.columns.values)
# Out:
# ['Unnamed: 0',
#  'Institution',
#  'Title',
#  'Annual Salary',
#  'FTE',
#  'APPT FTR BASIS',
#  'APPT FRACTION',
#  'AMOUNT OF SALARY PAID FROM GENERAL FUND',
#  '%',
#  'FTE.1',
#  'Time',
#  'PAY_FRCTN',
#  'Last Name',
#  'First Names',
#  'Department',
#  'FT/PT',
#  'Contract Length',
#  'Degree',
#  'Highest Education Level',
#  'Type',
#  'Effective Date',
#  'Hire Date',
#  'Ethnea',
#  'Genni',
#  'AdjSalary',
#  'PostdocNum',
#  'Assistant',
#  'Clinical',
#  'Faculty',
#  'Intern',
#  'Scholar',
#  'Fellow',
#  'Teaching',
#  'Researcher',
#  'Trainee',
#  'Senior',
#  'Associate',
#  'NIH_grants',
#  'NIH_order']

# %%
 d.to_csv("Tables/Preprocessed_dataset.csv")

# %%
set(d["Department"])
# Out:
# {nan,
#  'Molecular & Integrative Physl',
#  'Political Science',
#  'LSA Biophysics',
#  'Beckman Institute',
#  'Forest Biomaterials',
#  'ROSS SCH Management & Orgs.',
#  'Office of Academic Affairs',
#  'GEOGRAPHY ENVIRONMENT SPATIAL SCIENCES',
#  'Nutritional Sciences',
#  'Ctr. for Geospatial Analytics',
#  'Human Genetics Department',
#  'COS BIOLOGY',
#  'Coordinated Science Lab',
#  'COMPUTATIONAL MATH SCI AND ENGR CNS',
#  'SOM-MED-GASTROENTEROLOGY',
#  'Pediatrics-Endocrinology',
#  'LSA Kelsey Museum of Arch',
#  'ROSS SCH Ctr for Positive Orgs',
#  'COE ELECTRICAL ENGINEERING',
#  'U of M Energy Institute',
#  'CENTER FOR THE STUDY OF CURRICULUM',
#  'SOM-MED-INFECTIOUS DISEASE',
#  'Mathematics',
#  'SOM-SRG-VS CLINICAL',
#  'School of Dentistry',
#  'LSA Near Eastern Studies',
#  'COM IM Pulmonary Division',
#  'Chemical & Biomolecular C&G',
#  'UMTRI-Engineering Systems',
#  'UHS Varsity Village A',
#  'Nuclear Eng & Radiological Sci',
#  'COM Pathology Hui Lab',
#  'Materials Science &Engineering',
#  'Radiation Oncology - Physics',
#  'COE CIVIL ENGINEERING',
#  'Information Trust Institute',
#  'BIOCHEMISTRY',
#  'CQSB research',
#  'DLHS Division of LKS',
#  'COM Can Bio Zhang Lab',
#  'Pharmacy Practice and Admin Sciences',
#  'CASA-CTR,ASTROPHYS&SPACE ASTRO',
#  'CECH Education',
#  'Entomology',
#  'SOM-IMMUNOLOGY MICROBIOLOGY',
#  'Psych HlthSvc Outcome Research',
#  'SOM-SRG-GI CLINICAL',
#  'COM Can Bio Du Lab',
#  'SOM-MED-GIM',
#  'SOM-RADIATION ONCOLOGY',
#  'ANIMAL CARE PROGRAM',
#  'Neurology Department',
#  'COM Can Bio Plas Lab',
#  'SOM-PEDS GENERAL PEDS-GENOPS',
#  'ENGR-ELECTRICAL',
#  'Depression Center',
#  'SOM-MED-BIOMED',
#  'SOM-MED-HCP&R GEN OPERATIONS',
#  'Pediatric Surgery Section',
#  'CECH Criminal Justice',
#  'CEAS - Biomedical Eng',
#  'COM Pathology Tso Lab',
#  'Micro and Nanotechnology Lab',
#  'SOM-SRG-PEDS CLINICAL',
#  'PHYSIOLOGY HUMAN MEDICINE',
#  'SRC-Quantitative Methods',
#  'Mechanical Sci & Engineering',
#  'Physics',
#  'SOM-ANESTHESIOLOGY',
#  'COEHD ACAD TEACHER EXCELLENCE',
#  'LSA History',
#  'Dbn Col of Eng-Electric & Comp',
#  'Graham Sustainability Inst.',
#  'COM Mol Gen T Thompson Lab',
#  'SOM-SRG-CT CLINICAL',
#  'COM IM Immunology Division',
#  'PHYSIOLOGY NATURAL SCIENCE',
#  'SOM-MED-ONCOLOGY',
#  'Electrical & Computer Eng',
#  'IL Natural History Survey',
#  'English',
#  'Crop & Soil Sciences',
#  'COM Psychiatry Sah',
#  'COM EH EGMT Puga Lab',
#  'Asian American Studies',
#  'PHYSICS-ASTRONOMY',
#  'Chemical & Biomolecular Engr',
#  'PSYCHOLOGY SOCIAL SCIENCE',
#  'Institute for Genomic Biology',
#  'ENTOMOLOGY AGRICULTURE AND NATURAL RES',
#  'COM IM Infectious Diseases Division',
#  'CLAS-BIOLOGY',
#  'SOM-NEUROLOGY',
#  'HUMAN DEVELOPMENT & FAMILY STUDIES - CSS',
#  'BIO/COMPUTATIONAL EVOLUTION IN ACTION',
#  'SRC-Innovation,Netwrks&Knwldge',
#  'Biotechnology Teaching',
#  'COE MECHANICAL ENGINEERING',
#  'Cell & Developmental Biology',
#  'FAMILY MEDICINE, DEPARTMENT OF',
#  'SOM-RM PHYSICAL THERAPY',
#  'FREEDM Center',
#  'Sch of Nat Resources & Environ',
#  'Counseling Services',
#  'Astronomy',
#  'SOM-MED-RENAL GENERAL',
#  'School of Medicine',
#  'Pediatrics-Nephrology',
#  'School of Pharmacy',
#  'SOM-PEDS NUTRITION-SALSVR',
#  'ANIMAL SCIENCE DEPARTMENT ANR',
#  'Psychiatry-ASAP',
#  'SOM-MED-CARDIOLOGY',
#  'INTEGRATIVE BIOLOGY',
#  'LSA Molec./Cell./Develop. Bio',
#  'COM EH Bio Medvedovic Lab',
#  'Pharmacy Pauletti Lab',
#  'Cell and Developmental Biology',
#  'Clinical Pharmacy',
#  'Urology',
#  'COM Can Bio Biology Ben-Jonathan Lab',
#  'Hlth Behavior & Hlth Ed Dept',
#  'Hoxworth Research',
#  'GEOGRAPHY DEPARTMENT',
#  'Sci, Tech, Engr & Math (STEM)',
#  'PACKAGING',
#  'Pediatrics-Hematology/Oncology',
#  'UMTRI-Human Factors',
#  'CAHS Communication Sciences & Disorders',
#  'History',
#  'Foreign Languages And Literatu',
#  'RESEARCH TECHNOLOGY SUPPORT FACILTY',
#  'BIOCHEMISTRY & MOLECULAR BIOLOGY CNS',
#  'Philosophy & Religious Studies',
#  'SOM-BARBARA DAVIS CENTER',
#  'PEDIATRICS AND HUMAN DEVELOPMENT',
#  'Pharmacy Pharmaceutical Sciences',
#  'BIOFRONTIERS INSTITUTE',
#  'Geography & Geographic InfoSci',
#  'CSPH-AIANP AP/G',
#  'Physics Grads & Temps',
#  'Int Med-Hematology/Oncology',
#  'Population Studies Center',
#  'NC Inst of Climate Studies',
#  'ENGR-CIVIL',
#  'LSA Chemistry',
#  'Ag & Resource Economics',
#  'Department of Radiology',
#  'Biomedical Program - ENG',
#  'SOM-MED ADMIN RESEARCH',
#  'Adv Simulation of Lght Wt Rect',
#  'RCGD-Rsrch Cntr for Grp Dyn',
#  'A&S Geology',
#  'COM Surgery Research',
#  'Computer Science',
#  'Bioengineering',
#  'Textile & Apparel, Technology',
#  'COM Pathology & Lab Medicine',
#  'COM Psychiatry Clinical Research',
#  'DENT Periodontics and Oral Med',
#  'AGRICULTURAL FOOD AND RESOURCE ECONOMICS',
#  'OBSTETRICS GYNECOLOGY & REPRODUCTIVE BIO',
#  'KELLOGG BIOLOGICAL STATION NAT. SCI.',
#  'SOM-PSYCH BEH H&W SPR/GIFT',
#  'Recreation, Sport and Tourism',
#  'PHARMACY Pharmaceutical Sci',
#  'FACILITY FOR RARE ISOTOPE BEAMS',
#  'CSPH-CBH GENERAL OPS',
#  'CHEMISTRY',
#  'COM Emergency Medicine A',
#  'PHYSICS',
#  'Ophthalmology & Visual Science',
#  'Dermatology Department',
#  'School of Nursing',
#  'Emergency Med Critical Care',
#  'SOM-BIOCHEM&MOLECULAR GENETICS',
#  'COS GEOLOGICAL SCIENCE',
#  "COE Dean's Office",
#  'A&S Biological Sciences',
#  'CEAS - Biomedical, Chemical, and Env Eng',
#  'MICROBIOLOGY & MOLECULAR GENETICS CNS',
#  "NAT'L SUPERCONDUCTING CYCLOTRON LAB",
#  'SNRE Erb Institute',
#  'Pediatrics-Infectious Diseases',
#  'Anthropology',
#  'Adv Self-pwr Sys Integr SensrT',
#  'Microbiology',
#  'Surgery Department',
#  'Comp Med and Bioinformatics',
#  'BTEC-Biomfg Training Ed Ctr',
#  'Pharmacology Department',
#  'COMPUTER SCIENCE AND ENGINEERING',
#  'Mechanical Engineering',
#  'Agr & Consumer Economics',
#  'CPS- Ctr for Political Studies',
#  'Electrical & Computer Engr.',
#  'COB Marketing',
#  'COMMUNICATION',
#  'Biological And Agricultural En',
#  'Pediatrics-Pulmonary Medicine',
#  'COM Can Bio Price Lab',
#  'Cardiac Surgery',
#  'SOM-SRG-UR DIV CLINICAL',
#  'Forest Biotech Program',
#  'COM Psychiatry Basic Research',
#  'Law Research Faculty Activity',
#  'CHEMICAL ENGINEERING & MATERIALS SCIENCE',
#  'Materials Science & Engineerng',
#  'Inst for Sustain, Enrgy, & Env',
#  'SOM-PEDS NEUROLOGY-GENOPS',
#  'ADVANCE Program',
#  'IL State Water Survey',
#  'Power America - ECE',
#  'COM Can Bio Guan Lab',
#  'Biostatistics Department',
#  'CEAS - Aerospace Eng',
#  'Civil Const & Environ Engineer',
#  'Prestage Poultry Science',
#  'PHILOSOPHY',
#  'Business Administration',
#  'Materials Science & Engin.',
#  'Media and Cinema Studies',
#  'LSA Anthropology',
#  'A&S Psychology',
#  'Dept Molecular Biomedical Scie',
#  'Industrial & Operations Engin',
#  'Civil & Environmental Eng',
#  'EECS - CSE Division',
#  'SOM-OPHTHALMOLOGY',
#  'Obstetrics and Gynecology Dept',
#  'SRC-Survey Methodology',
#  'Geology',
#  'Plant Biology',
#  'CENTER FOR GLOBAL CONNECTIONS CGC',
#  'TRANSLATION SCIENCE & MOLECULAR MED',
#  'Civil & Environmental Engr',
#  "EDUC-DEAN'S OFFICE",
#  'CEAS - Mechanical Eng',
#  'COS COMPUTER SCIENCE',
#  'Textile Engineering, Chemistry',
#  'Child Behavioral Health',
#  'LSA II: Weiser Emerging Democr',
#  'CREATE FOR STEM',
#  'MCDB-INSTRUCTION',
#  'COM IM Hematology/Oncology Division',
#  'COE Climate & Space',
#  'Animal Sciences',
#  'Pharmacy Kasting Lab',
#  'CEAS - Mech Eng and Materials Eng',
#  'Psych Labs and Bioinformatics',
#  'Engineering-Academic Affairs',
#  'A&S Physics Post Docs',
#  'COM Neurology Seroogy Lab',
#  'Agricultural & Biological Engr',
#  'EARTH AND ENVIRONMENTAL SCIENCES',
#  'SOM-LINDA CRNIC INST GEN OPS',
#  'A&S Mathematical Sciences',
#  'SOM-MED-CLINICAL PHARMACOLOGY',
#  'Crop Sciences',
#  'TEACHER EDUCATION',
#  'SOM-DERMATOLOGY',
#  'COM Anesthesiology',
#  'CEAS - Materials Eng',
#  'School of Social Work',
#  'Anesthesiology Department',
#  'Molec & Integrative Physiology',
#  'COM Cancer Biology Chen Lab',
#  'POLITICAL SCIENCE',
#  'Int Med-Nephrology',
#  'School of Labor & Empl. Rel.',
#  'PHYSIOLOGY OSTEOPATHIC MEDICINE',
#  'SRC - Youth & Social Issues',
#  'SDM-CRANIOFACIAL BIOLOGY',
#  'CLINICAL AND TRANSLATIONAL SCIENCES',
#  'SOM-SRG-SURG ONC CLINICAL',
#  'Molecular & Behav Neurosc Inst',
#  'Food Science & Human Nutrition',
#  'STATISTICS & PROBABILITY',
#  'COM Mol Gen Kovall Lab',
#  'CENTER FOR DRUG DISCOVERY',
#  'COM EH EGMT Burns Lab',
#  'CSPH-BIO INFO GENERAL OPS',
#  'COM Environmental Health',
#  'DEPARTMENT OF MEDIA AND INFORMATION',
#  'Orthopaedic Surgery',
#  'COM Psychiatry Ulrich-Lai',
#  'COE Biomedcial Engineering',
#  'LARGE ANIMAL CLINICAL SCIENCES',
#  'CoE Center for Health Eng',
#  'COM Can Bio Waltz Lab',
#  'Radiation Oncology - Can Bio',
#  'Psychology',
#  'LSA Complex Systems',
#  'LSA Philosophy',
#  'Biomedical Engineering',
#  'SOM-MED-PULMONARY DISEASE',
#  'SOM-PSYCH DPRG SPG/GIFT',
#  'Pediatrics-Genetics',
#  'SOM-RADIOLOGY',
#  'SOM-MED-BONEMARROW TRANSPLANT',
#  'DENT Ortho/Peds Dentistry',
#  'Law Clinical Activity',
#  'Chemical Engineering Dept',
#  'KCLDS',
#  'Urban Planning',
#  'SRC-Hrs',
#  'Dbn Coll of Eng-Mechanical Eng',
#  'SRC-Psid',
#  'SOM-CELL AND DEVOPMENTAL BIO',
#  'COM Pathology Xu Lab',
#  'COLFA ANTHROPOLOGY',
#  'SOM-OTOLARYNGOLOGY',
#  'LSA History of Art',
#  'RADIOLOGY HUMAN MEDICINE',
#  'Marine, Earth And Atmospheric',
#  'Kinesiology & Community Health',
#  'Entomology & Plant Pathology',
#  'Food,Bioprocess & Nutrition Sc',
#  'Educational Psychology',
#  'Law',
#  'CIVIL & ENVIRONMENTAL ENGINEERING',
#  'School of Kinesiology',
#  'Design Research',
#  'COMMUNICATIVE SCIENCES DISORDERS CAS',
#  'Statistics',
#  'SOP-ADMINISTRATION',
#  'Biochemistry',
#  'PHARMACOLOGY TOXICOLOGY',
#  'COM Mol Gen Lingrel Lab',
#  'COE Civil Engineering',
#  'SOM-HEALTH AND WELLNESS CENTER',
#  'Latina/Latino Studies',
#  'SOM-OB/GYN BRS',
#  'Natural Res & Env Sci',
#  'SOM-NEUROSURGERY',
#  'COE EECS - ECE Division',
#  'LSA Natl Ctr Inst Diversity',
#  'COM EH Epi Chen Lab',
#  'SOM-PEDS CARDIOLOGY-GENOPS',
#  'LSA Statistics',
#  'LSA Ecology & Evolutionary Bio',
#  'Emergency Medicine Research',
#  'Pathobiology',
#  'MI Nanotechnology Institute',
#  'Law School',
#  'OSTEOPATHIC MEDICAL SPECIALTIES COM',
#  'Microbiology and Immunology',
#  'COM Neurosurgery',
#  'Chemistry',
#  'LSA Earth & Environmental Sci.',
#  'Integrated Pest Mgmt-Research',
#  'SOM-MED-RHEUMATOLOGY',
#  'FER Tree Physiology',
#  'CRSC - Grants',
#  'LSA English Language & Lit.',
#  'Nonwovens Institute',
#  'For & Envir Res Acad Research',
#  'Biointerfaces',
#  'HORTICULTURE ANR',
#  'Information Sciences',
#  'COM PCB Kranias Lab',
#  'COM Cancer Biology',
#  'Computer Science-engr',
#  'Pathology Department',
#  'URBAN PLANNING',
#  'LSA Psychology',
#  'Int Med-Molecular Med&Genetics',
#  'Germanic Languages & Lit',
#  'COM PCB Fan Lab',
#  'CSPH-LEAD',
#  'MECHANICAL ENGINEERING',
#  'Plant and Microbial Biology',
#  'COUNSELING, EDUC PSYCH & SPEC EDUC',
#  'SOM-PEDS KEMPE-GENOPS',
#  'Vascular Surgery Section',
#  'COM EH EGMT Yadav Lab',
#  'COMMUNITY EVALUATION & RSCH COLLABRTVE',
#  'Int Med-Infectious Diseases',
#  'Dept-Population,Health,Pathobi',
#  'SOM-PATHOLOGY',
#  'EDUCATION DEAN',
#  'DENT Bio & Materials Science',
#  'KELLOGG BIO STATION MABR',
#  'COM EH EGMT Xia Lab',
#  'A&S Chemistry Post Docs',
#  'Int Med-Rheumatology',
#  'COM EH Epi-Bio Medvedovic Lab',
#  'Life Sciences Institute-Admin',
#  'PLANT RESEARCH LABORATORY NAT SCIENCE',
#  'Lab for Analytic Sciences',
#  'LSA DAAS',
#  'School of Information',
#  'Ctr fr Translational Pathology',
#  'Biological Chemistry Dept',
#  'LSA Economics',
#  'Animal Biology',
#  'Atmospheric Sciences',
#  'G. Ford Sc Pub Pol',
#  'PLANT BIOLOGY CNS',
#  'COS CHEMISTRY',
#  'Int Med-Cardiology',
#  'CENTER FOR MICROBIAL ECOLOGY ANR',
#  'Psychiatry Child Services',
#  'SOM-MED-ENDOCRINOLOGY',
#  'LSA Judaic Studies',
#  'Pgm for Res in the Humanities',
#  'GEOLOGICAL SCIENCES',
#  'Aerospace Engineering',
#  'IT SERVICES UNIVERSITY SYSTEMS',
#  'Int Med-Pulm./Critical Care',
#  'Kresge Hearing Research Inst',
#  'Materials Research Lab',
#  'COM Physiology Hogenesch Lab',
#  'IBG-INST,BEHAVIORAL GENETICS',
#  'CHEMICAL AND BIOLOGICAL ENGIN',
#  'CoE Ctr Eng Divers & Outrch',
#  'Center for Human Growth & Dev',
#  'EPIDEMIOLOGY AND BIOSTATISTICS',
#  'SOM-PEDS NEONATOLOGY-GENOPS',
#  'GSA - Administration (GSA/ADM)',
#  'PSYCH-PSYCHOLOGY',
#  'ArtsEngine',
#  'COE OCI',
#  'SOM-PSYCH-PHARM SP/G',
#  'Nuclear Engineering',
#  'LSA II: Nam Ctr Korean Studies',
#  'Psychiatry Depression Center',
#  'Sociology & Anthropology',
#  'HISTORY',
#  'COM UC Cancer Programs',
#  'CHM FLINT',
#  'A&S Geography',
#  'SOM-PEDS DEVL BIOLOGY-GENOP',
#  'EXTENSION HEALTH AND NUTRITION',
#  'SOM-MED-GERIATRICS',
#  'African American Studies',
#  'SNRE CILER',
#  'COM Psychiatry R McCullumsmith Lab',
#  'Applied Research Institute',
#  'BIOSYSTEMS AND AGRICULTURAL ENGINEERING',
#  'ELECTRICAL AND COMPUTER ENGINEERING',
#  'Mechanical & Aerospace Engr',
#  'Environmental Health Sciences',
#  'RADIOLOGY OSTEOPATHIC MEDICINE',
#  'Kannapolis Research',
#  'SOM-PEDS HEMATOLOGY-ONC-GENOPS',
#  'SOM-MED-CVP',
#  'Metabolism, Endo & Diabetes',
#  'NEUROSCIENCE PROGRAM',
#  'Parks, Recreation & Tourism Mg',
#  'CRSC  supplementary',
#  'SOM-MED-HEMATOLOGY',
#  'Supercomputing Applications',
#  'Fisheries and Wildlife Program',
#  'COM Pathology Research',
#  'COS PHYSICS & ASTRONOMY',
#  'Plastic Surgery Section',
#  'LSA Humanities Institute',
#  'Animal Science',
#  'CVM Teaching Hospital',
#  'Dept of Clinical Sciences',
#  'Education Administration',
#  'Psych Substance Abuse',
#  'COE BIOMEDICAL ENGINEERING',
#  'SO TX CTR EMERG INFECT DISEASE',
#  'Naval Arch & Marine Dept',
#  'COMPUTATIONAL MATH SCI AND ENGR EGR',
#  'SOM-PEDS JFK-CDU SALSVR',
#  'PHARMACY Medicinal Chemistry',
#  'Lab Animal Medicine Unit',
#  'MICROBIOLOGY AND MOLECULAR GENETICS COM',
#  'Epidemiology Department',
#  'FORESTRY',
#  'COM IM Cardiology Division',
#  'ADM Institute for PHL',
#  'SOM-MED-CLINICAL IMMUNOLOGY',
#  'NEUROSCIENCES INSTITUTE',
#  'CEAS - Chemical Eng',
#  'COM EH EGMT Ho Lab',
#  'FOOD SCIENCE AND HUM NUTRITION ANR',
#  'COM EH EGMT Kim Lab',
#  'ANTHROPOLOGY',
#  'INTEGRATIVE PHYSIOLOGY',
#  'Interdisciplinary Studies',
#  'LSA Astronomy',
#  'PATHOBIOLOGY DIAGNOSTIC INVESTIGAT CVM',
#  'SOE-Educational Studies',
#  'SOM - PHARMACOLOGY',
#  'Neurosurgery',
#  'LASP',
#  'MSUE DIRECTORS OFFICE',
#  'COM Pathology Wang Lab',
#  'SOM-PSYCH HARRIS RSCH SPG/GIFT',
#  'Emergency Medicine UM Adult',
#  'GLOBAL CHG & EARTH OBSERVATIONS, CTR FOR',
#  'FISHERIES AND WILDLIFE',
#  'Applied Ecology',
#  'COEHD HEALTH & KINESIOLOGY',
#  'PLANT SOIL AND MICROBIAL SCIENCES',
#  'Horticultural Science',
#  'COM Pathology Davidson Lab',
#  'Dance',
#  'INSTITUTE FOR INTEGRATIVE TOXICOLOGY',
#  'LSA II: Chinese Studies',
#  'SOM-PEDS ID-GENOPS',
#  'GREAT LAKES BIOENERGY RESEARC CTR VPRGS',
#  'SOM-EMERGENCY MEDICINE',
#  'CSPH-HSMP GENERAL OPS',
#  'COM  Ophthalmology Kao Lab',
#  'Comparative Biosciences',
#  'Biomedical Engineering - MS',
#  'Psychiatry-Neuropsychology',
#  'MATHEMATICS',
#  'Biological Sciences',
#  'CLAS-CHEMISTRY',
#  'CEAS - Elec Eng & Computing Systems',
#  'IL Sustainable Technology Ctr',
#  'Engineering Administration',
#  'College of Pharmacy',
#  'School of Education',
#  'ENGR-BIOENGINEERING',
#  'Vet Clinical Medicine',
#  'COM Orthopaedic Surgery',
#  'Int Med-General Medicine',
#  'Nuclear, Plasma, & Rad Engr',
#  'Family Medicine',
#  'PHARMACOLOGY & TOXICOLOGY HUMAN MEDICINE',
#  'Int Med-Gastroenterology',
#  'LSA Physics',
#  'SOM - PHYSIOLOGY',
#  'American Indian Studies Prgrm',
#  'COM Psychiatry & CPC',
#  'LSA Linguistics'}
